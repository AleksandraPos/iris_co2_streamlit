# %% [markdown]
# ## Plotly

# %%
! pip install plotly

# %%
import plotly.express as px
import pandas as pd
df = px.data.iris()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
my_df = pd.read_csv('data/geo_data.csv')
my_df
# Out:
#     Continent_Name Continent_Code  \
# 0             Asia             AS
# 1           Europe             EU
# 2       Antarctica             AN
# 3           Africa             AF
# 4          Oceania             OC
# ..             ...            ...
# 257         Africa             AF
# 258        Oceania             OC
# 259           Asia             AS
# 260           Asia             AS
# 261           Asia             AS
#
#                                      Country_Name Two_Letter_Country_Code  \
# 0                Afghanistan, Islamic Republic of                      AF
# 1                            Albania, Republic of                      AL
# 2    Antarctica (the territory South of 60 deg S)                      AQ
# 3        Algeria, People's Democratic Republic of                      DZ
# 4                                  American Samoa                      AS
# ..                                            ...                     ...
# ...

# %%
fig = px.scatter(df, x='sepal_width', y='sepal_length')
fig.show()

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species',
#        'species_id'],
#       dtype='object')

# %%
fig = px.scatter(df, x='sepal_width',
                 y='sepal_length',
                 color='species',
                 size='petal_length',
                 hover_data=['petal_width'])
fig.show()

# %%
fig = px.scatter(df, x='sepal_width',
                 y='sepal_length',
                 color='species',
                 size='petal_length',
                 hover_data=['petal_width'],
                 marginal_x='box')
fig.show()

# %%
fig = px.scatter(df, x='sepal_width',
                 y='sepal_length',
                 color='species',
                 size='petal_length',
                 hover_data=['petal_width'],
                 marginal_x='box',
                 marginal_y = 'box')
fig.show()

# %%
fig = px.scatter(df, x='sepal_width',
                 y='sepal_length',
                 color='species',
                 size='petal_length',
                 hover_data=['petal_width'],
                 marginal_x='histogram',
                 marginal_y = 'histogram'
                 ,trendline='ols'
                 )

#effacer la grille 
fig.update_layout(
    xaxis=dict(showgrid=False),
    yaxis=dict(showgrid=False)
)

fig.show()

# %%
df_setosa = df[df['species']=='setosa']
df_virginica = df[df['species']=='virginica']
df_versicolor = df[df['species']=='versicolor']

# %%
df_setosa.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width  species_id
# sepal_length      1.000000     0.746780      0.263874     0.279092         NaN
# sepal_width       0.746780     1.000000      0.176695     0.279973         NaN
# petal_length      0.263874     0.176695      1.000000     0.306308         NaN
# petal_width       0.279092     0.279973      0.306308     1.000000         NaN
# species_id             NaN          NaN           NaN          NaN         NaN

# %%
df_versicolor.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width  species_id
# sepal_length      1.000000     0.525911      0.754049     0.546461         NaN
# sepal_width       0.525911     1.000000      0.560522     0.663999         NaN
# petal_length      0.754049     0.560522      1.000000     0.786668         NaN
# petal_width       0.546461     0.663999      0.786668     1.000000         NaN
# species_id             NaN          NaN           NaN          NaN         NaN

# %%
#histogram

fig = px.histogram(df, x="sepal_width")
fig

# %%
#Violin plot 


fig = px.violin(df, y="sepal_width", color="species_id")
fig.show()

# %%
fig = px.violin(df
                , y="sepal_width"
                , color="species"
                , box=True
                , points='all')
fig.show()

# %%
df.groupby('species').count().reset_index()
# Out:
#       species  sepal_length  sepal_width  petal_length  petal_width  \
# 0      setosa            50           50            50           50
# 1  versicolor            50           50            50           50
# 2   virginica            50           50            50           50
#
#    species_id
# 0          50
# 1          50
# 2          50

# %%
df.groupby('species').sum().reset_index()
# Out:
#       species  sepal_length  sepal_width  petal_length  petal_width  \
# 0      setosa         250.3        170.9          73.2         12.2
# 1  versicolor         296.8        138.5         213.0         66.3
# 2   virginica         329.4        148.7         277.6        101.3
#
#    species_id
# 0          50
# 1         100
# 2         150

# %%
#Pie chart 

fig = px.pie(df.groupby('species').count().reset_index(), 
             values='sepal_length', names='species', 
             title='Propotion Cat')
fig.show()

# %%
fig = px.pie(df.groupby('species').sum().reset_index(), 
             values='sepal_length', names='species', 
             title='Total sepal length by species')
fig.show()

# %%
#parallel Coordinate

# %%
df[['species', 'species_id']]
# Out:
#        species  species_id
# 0       setosa           1
# 1       setosa           1
# 2       setosa           1
# 3       setosa           1
# 4       setosa           1
# ..         ...         ...
# 145  virginica           3
# 146  virginica           3
# 147  virginica           3
# 148  virginica           3
# 149  virginica           3
#
# [150 rows x 2 columns]

# %%
fig = px.parallel_coordinates(df, color="species_id"
                              )
fig.show()

# %% [markdown]
# # 3D PLot

# %%
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', 
                    z='petal_width', color='species')
fig.show()

# %%
# Maps 


co2 = pd.read_csv('data/CO2_per_capita.csv', sep=";")

co2 = co2.dropna().sort_values('Year')

# TODO: Visualize your data on a World map
fig = px.scatter_geo(co2, locations="Country Code",
                    # color="continent", # which column to use to set the color of markers
                    hover_name="Country Name", # column added to hover information
                    size="CO2 Per Capita (metric tons)", # size of markers
                    animation_frame='Year')
fig.show()
